# %% [markdown]
# <a href="https://colab.research.google.com/github/ysy202202256/python/blob/main/%EB%85%BC%ED%94%84_%EA%B3%BC%EC%A0%9C4%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2.1, 0.1)
y = x**2 + np.sin(3*x+7)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a**2 + b**2 + 1

def grad_f(a,b): # gradient
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		# update parameters:
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-2.5, -2.5], iters = 50, alpha = 0.05)

# f(x,y) = x^2 + y^2 + 1의 그래프 그리기
fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
a = np.arange(-3, 3, 0.1)
b = np.arange(-3, 3, 0.1)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

##plt.axis('equal')

plt.show()
# Out:
# [13.5        11.125       9.20125     7.6430125   6.38084012  5.3584805
#   4.53036921  3.85959906  3.31627524  2.87618294  2.51970818  2.23096363
#   1.99708054  1.80763524  1.65418454  1.52988948  1.42921048  1.34766049
#   1.28160499  1.22810005  1.18476104  1.14965644  1.12122172  1.09818959
#   1.07953357  1.06442219  1.05218197  1.0422674   1.03423659  1.02773164
#   1.02246263  1.01819473  1.01473773  1.01193756  1.00966943  1.00783223
#   1.00634411  1.00513873  1.00416237  1.00337152  1.00273093  1.00221205
#   1.00179176  1.00145133  1.00117558  1.00095222  1.0007713   1.00062475
#   1.00050605  1.0004099   1.00033202]

# %%
sns.set_theme()

sns.scatterplot(x = "Volume (ml)", y = "Calories", data = df,  hue = 'type')

# %%
sns.histplot(y = "Caffeine (mg)", data = df)

# %%
sns.histplot(x = "Caffeine (mg)", data = df)

# %%
sns.barplot(x = "Volume (ml)", y = "type", data = df)

# %%
sns.boxplot(x = "Caffeine (mg)", y = "type", data=df)
