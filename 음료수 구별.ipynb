# %% [markdown]
# <a href="https://colab.research.google.com/github/ysy202202256/python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

targetUrl = 'https://raw.githubusercontent.com/ysy202202256/python/main/caffeine.csv'
df = pd.read_csv(targetUrl)

normalization_df = (df - df.mean())/df.std()
X = normalization_df.iloc[:, 0:3]

y = df.iloc[:, 4]
y = pd.get_dummies(y)

model = Sequential()

model.add(Dense(20, input_dim=3, activation='relu'))
model.add(Dense(35, activation='sigmoid'))
model.add(Dense(6, activation='softmax'))

model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, y, epochs=20000, batch_size=25)
loss = model.evaluate(X,y)

print('loss :', loss)

plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   if __name__ == '__main__':
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 17502/20000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9246
# Epoch 17503/20000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9279
# Epoch 17504/20000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9295
# Epoch 17505/20000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9344
# Epoch 17506/20000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9295
# Epoch 17507/20000
# ...

# %% [markdown]
# # 새 섹션
